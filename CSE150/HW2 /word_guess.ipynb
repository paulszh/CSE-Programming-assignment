# %%
mydict = {}
with open ('hw2_word_counts_05.txt') as datafile:
    for line in datafile:
        pair = line.split()
        mydict[pair[0]] = pair[1]

# %%
list(mydict.keys())[5]
print (len(mydict))
sorted(myDict, key=myDict.get, reverse=True)
# Out:
# 6535
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-49892fd52341> in <module>()
#       1 list(mydict.keys())[5]
#       2 print (len(mydict))
# ----> 3 sorted(myDict, key=myDict.get, reverse=True)
#
# NameError: name 'myDict' is not defined

# %%
sorted_names = sorted(mydict, key=lambda x: mydict[x])
for k in sorted_names:
    print("{} : {}".format(k, mydict[k]))
# Out:
# AZURE : 10
# BORES : 10
# CAFFE : 10
# CASKS : 10
# CHAND : 10
# CHLOE : 10
# CHOUF : 10
# CYBER : 10
# DEUTZ : 10
# DINGS : 10
# DIODE : 10
# DUBIN : 10
# ELSEY : 10
# EPICS : 10
# FOLIO : 10
# GEIER : 10
# GLINT : 10
# GNATS : 10
# HOYAS : 10
# ISAMU : 10
# ISGRO : 10
# ISLIP : 10
# KAMIL : 10
# KAZEM : 10
# KEIKO : 10
# LADER : 10
# LAHAD : 10
# LAVON : 10
# LEPER : 10
# MAKIN : 10
# MASSA : 10
# MITRE : 10
# MOPED : 10
# MUDAR : 10
# MUMBO : 10
# NAHAT : 10
# NAJAH : 10
# NEORX : 10
# NISHI : 10
# PERCE : 10
# RANCE : 10
# ROWED : 10
# SAADI : 10
# SAMBO : 10
# SCOWL : 10
# SIGLO : 10
# TANIA : 10
# TATRA : 10
# TEALE : 10
# TEEMS : 10
# TONYS : 10
# TOTES : 10
# TUBAS : 10
# UNIFI : 10
# VEERS : 10
# AWOKE : 100
# BASEL : 100
# BOOBY : 100
# DUPED : 100
# GACHA : 100
# GENIE : 100
# GILES : 100
# GUBER : 100
# MOMMY : 100
# OATES : 100
# RIZZO : 100
# SOUZA : 100
# STRAP : 100
# VIALS : 100
# STOPS : 1000
# LOYAL : 1007
# NOTES : 10085
# GRACE : 1009
# TERMS : 10091
# ...
